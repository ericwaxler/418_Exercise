# %%
import pandas as pd
import matplotlib.pyplot as plt
#import plotly.plotly as py
#import cufflinks as cf
import pandas as pd

# %%
csv2 = "true_car_listings.csv"
df2 = pd.read_csv(csv2, error_bad_lines=False)
#df2.head()
#df2.keys()

# %%
csv1 = "true_car_listings.csv"
df = pd.read_csv(csv1, error_bad_lines=False)
df.head()

Milage = [0,20000,50000 , 90000, 140000, 200000, 5000000]

Milage_Group = ["0 - 20K", "15K-50K", "50K-90K", "90K-140K", "140K-200K",">200K"] 

df["Car Milage Group"] = pd.cut(df["Mileage"], Milage, labels= Milage_Group)
#df.sort_values('Car Milage Group', ascending=True)
#df.head()
#df=df.groupby(['Car Milage Group','Make','State'])['Price'].mean()
df.head()
#df3.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model Car Milage Group
# 0    ILX6-Speed          15K-50K
# 1    ILX5-Speed          0 - 20K
# 2    ILX6-Speed          15K-50K
# 3    ILX5-Speed          15K-50K
# 4  ILXAutomatic          15K-50K

# %%
#df.groupby("Car Milage Group").value()
#df.groupby(['col5','col2']).reset_index()
#Df3=df.sort_values(['Car Milage Group','Price'])
#Df3.groupby('Make')

#df.groupby('Car Milage Group').value_counts()
#Df3.head()
ax = df.plot.scatter(x='x', y='y', s=s, alpha=0.5)
df.plot(kind='bubble', x=df["State"], y=df.groupby(['Make','State'])['Price'].mean(), size='pop', text='country')
             #xTitle='GDP per Capita', yTitle='Life Expectancy',
             #filename='cufflinks/simple-bubble-chart')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-d397660c30fa> in <module>
#       6 #df.groupby('Car Milage Group').value_counts()
#       7 #Df3.head()
# ----> 8 df.plot(kind='bubble', x=df["State"], y=df.groupby(['Make','State'])['Price'].mean(), size='pop', text='country')
#       9              #xTitle='GDP per Capita', yTitle='Life Expectancy',
#      10              #filename='cufflinks/simple-bubble-chart')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
ax = df.plot.scatter(x='x', y='y', alpha=0.5)
for i, txt in enumerate(df.users):
    ax.annotate(txt, (df.x.iat[i],df.y.iat[i]))
plt.show()

# %%
df['Model'].value_counts()
# Out:
# Silverado           24932
# Grand               17321
# Accord              14502
# F-1504WD            14177
# Altima2.5           11288
# Civic               11273
# Sierra              11208
# 3                   11131
# Wrangler             7975
# Super                7953
# Jetta                7340
# Santa                6708
# FusionSE             6388
# EquinoxFWD           6224
# Tundra               5449
# 5                    5348
# RX                   5327
# F-1502WD             5144
# CamrySE              4825
# FocusSedan           4642
# Town                 4530
# MalibuLT             4515
# ES                   4426
# EscapeFWD            4245
# CorollaLE            4172
# Rover                4096
# Cooper               4027
# Ram                  3990
# CamaroCoupe          3881
# IS                   3708
#                     ...
# RegalSedan              1
# Challenger              1
# 9-5Base                 1
# 300C                    1
# ...

# %%
df3 = df2.groupby('State')['Make'].value_counts()

# %%
df3.head(50)
# Out:
# State  Make
#  AK    Ford              490
#        Chevrolet         421
#        Toyota            231
#        Nissan            221
#        Jeep              132
#        Dodge             129
#        GMC               124
#        Kia                77
#        Hyundai            62
#        Subaru             46
#        Chrysler           45
#        Ram                35
#        Honda              30
#        Volkswagen         28
#        Cadillac           21
#        Mercedes-Benz      19
#        Mazda              17
#        BMW                14
#        Buick              13
#        Lexus              11
#        Lincoln            10
#        HUMMER              9
#        Scion               8
#        INFINITI            6
#        Mitsubishi          6
#        Acura               5
#        MINI                5
#        Audi                4
#        Land                4
#        Pontiac             4
#        Suzuki              4
# ...
